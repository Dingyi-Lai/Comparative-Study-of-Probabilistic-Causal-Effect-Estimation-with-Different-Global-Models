# %%
# Record the running time

# Inbuilt or External Modules
import argparse # customized arguments in .bash
import csv # input and output .csv data
import glob # file matching using wildcards
import numpy as np # for numerical computing
import os # OS routines
# import pdb # debugger, but it doesn't work remotely
import pandas as pd

# Customized Modules
from configs.global_configs import hyperparameter_tuning_configs
from configs.global_configs import model_testing_configs
from error_calculator.final_evaluation import evaluate
from utility_scripts.ensembling_forecasts import ensembling_forecasts
# from utility_scripts.invoke_final_evaluation import invoke_script # for invoking R
from utility_scripts.hyperparameter_scripts.hyperparameter_config_reader import read_initial_hyperparameter_values, read_optimal_hyperparameter_values
from utility_scripts.persist_optimized_config_results import persist_results
# import SMAC utilities
# import the config space and the different types of parameters

# stacking model
from rnn_architectures.stacking_model_p import StackingModel


LSTM_USE_PEEPHOLES = True # LSTM with “peephole connections"
BIAS = False # in tf.keras.layers.dense

# arguments with no default values
dataset_name = "sim_10_60_l_he"
no_of_series = int(10)
initial_hyperparameter_values_file = "configs/initial_hyperparameter_values/ems_adagrad"
binary_train_file_path_train_mode = "datasets/binary_data/sim/moving_window/sim_10_60_linear_heterogeneous_train_12_15.tfrecords"
binary_validation_file_path_train_mode = "datasets/binary_data/sim/moving_window/sim_10_60_linear_heterogeneous_validation_12_15.tfrecords"
binary_test_file_path_test_mode = "datasets/binary_data/sim/moving_window/sim_10_60_linear_heterogeneous_test_12_15.tfrecords"
output_size = 12
txt_test_file_path = "datasets/text_data/sim/moving_window/sim_10_60_linear_heterogeneous_test_12_15.txt"
actual_results_file_path = "datasets/text_data/sim/sim_10_60_linear_heterogeneous_test_actual.csv"
original_data_file_path = "datasets/text_data/sim/sim_10_60_linear_heterogeneous_train.csv"
seasonality_period = 12
seed = 1234
cell_type = "LSTM"
optimizer = "cocob"
evaluation_metric = "CRPS"
stl_decomposition_identifier = "without_stl_decomposition"
model_identifier = dataset_name + "_" + cell_type + "cell" + "_" +  optimizer + "_" + \
                       stl_decomposition_identifier
input_size = 16
contain_zero_values = 0
address_near_zero_instability = 0
integer_conversion = 0
quantile_range = [0.1,0.5,0.9]
without_stl_decomposition = bool(int(1))
print("Model Training Started for {}".format(model_identifier))


# define the key word arguments for the different model types
model_kwargs = {
    'use_bias': BIAS,
    'use_peepholes': LSTM_USE_PEEPHOLES,
    'input_size': input_size,
    'output_size': output_size,
    'optimizer': optimizer,
    'quantile_range': quantile_range,
    'evaluation_metric': evaluation_metric,
    'no_of_series': no_of_series,
    'binary_train_file_path': binary_train_file_path_train_mode,
    'binary_test_file_path': binary_test_file_path_test_mode,
    'binary_validation_file_path': binary_validation_file_path_train_mode,
    'contain_zero_values': contain_zero_values,
    'address_near_zero_instability': address_near_zero_instability,
    'integer_conversion': integer_conversion,

    'seed': seed,
    'cell_type': cell_type,
    'without_stl_decomposition': without_stl_decomposition
}

# select the model type
model = StackingModel(**model_kwargs)
# Out:
# Using TensorFlow backend.
# 2024-02-02 12:04:14.570382: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-02 12:04:14.570492: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-02 12:04:14.572359: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-02 12:04:17.338800: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 15
#      13 from configs.global_configs import hyperparameter_tuning_configs
#      14 from configs.global_configs import model_testing_configs
# ---> 15 from error_calculator.final_evaluation import evaluate
#      16 from utility_scripts.ensembling_forecasts import ensembling_forecasts
#      17 # from utility_scripts.invoke_final_evaluation import invoke_script # for invoking R
#
# File ~/master_thesis/error_calculator/final_evaluation.py:4
#       2 import numpy as np
#       3 from scipy.interpolate import CubicSpline
# ----> 4 from quantile_utils.CRPS_QL import mean_weighted_quantile_loss
#       5 import pickle
#       7 # def custom_smape(forecasts, actual, epsilon=0.1):
#       8 #     comparator = 0.5 + epsilon
#       9 #     sum_term = np.maximum(comparator, (np.abs(forecasts) + np.abs(actual) + epsilon))
#      10 #     return 2 * np.abs(forecasts - actual) / sum_term
#
# File ~/master_thesis/quantile_utils/CRPS_QL.py:2
#       1 import numpy as np
# ----> 2 from keras.utils import losses_utils
#       3 from keras.losses import LossFunctionWrapper
#       4 import tensorflow as tf
#
# File ~/.local/lib/python3.10/site-packages/keras/__init__.py:3
#       1 from __future__ import absolute_import
# ----> 3 from . import utils
#       4 from . import activations
#       5 from . import applications
#
# File ~/.local/lib/python3.10/site-packages/keras/utils/__init__.py:26
#      24 from .layer_utils import get_source_inputs
#      25 from .layer_utils import print_summary
# ---> 26 from .vis_utils import model_to_dot
#      27 from .vis_utils import plot_model
#      28 from .np_utils import to_categorical
#
# File ~/.local/lib/python3.10/site-packages/keras/utils/vis_utils.py:7
#       4 from __future__ import print_function
#       6 import os
# ----> 7 from ..models import Model
#       8 from ..layers.wrappers import Wrapper
#      10 # `pydot` is an optional dependency,
#      11 # see `extras_require` in `setup.py`.
#
# File ~/.local/lib/python3.10/site-packages/keras/models.py:10
#       8 from .utils.generic_utils import has_arg
#       9 from .utils.generic_utils import to_list
# ---> 10 from .engine.input_layer import Input
#      11 from .engine.input_layer import InputLayer
#      12 from .engine.training import Model
#
# File ~/.local/lib/python3.10/site-packages/keras/engine/__init__.py:8
#       6 from .base_layer import Layer
#       7 from .network import get_source_inputs
# ----> 8 from .training import Model
#
# File ~/.local/lib/python3.10/site-packages/keras/engine/training.py:14
#      12 from .network import Network
#      13 from .base_layer import Layer
# ---> 14 from . import training_utils
#      15 from . import training_arrays
#      16 from . import training_generator
#
# File ~/.local/lib/python3.10/site-packages/keras/engine/training_utils.py:17
#      15 from .. import backend as K
#      16 from .. import losses
# ---> 17 from .. import metrics as metrics_module
#      18 from ..utils import Sequence
#      19 from ..utils import generic_utils
#
# File ~/.local/lib/python3.10/site-packages/keras/metrics.py:1850
#    1848     import tensorflow as tf
#    1849     if tf.__version__ >= '2.0.0':
# -> 1850         BaseMeanIoU = tf.keras.metrics.MeanIoU
#    1853 class MeanIoU(BaseMeanIoU):
#    1854     """Computes the mean Intersection-Over-Union metric.
#    1855
#    1856     Mean Intersection-Over-Union is a common evaluation metric for semantic image
#    (...)
#    1881         dtype: (Optional) data type of the metric result.
#    1882     """
#
# File ~/.local/lib/python3.10/site-packages/tensorflow/python/util/lazy_loader.py:146, in KerasLazyLoader.__getattr__(self, item)
#     144   return super(types.ModuleType, self).__getattribute__(item)
#     145 if not self._initialized:
# --> 146   self._initialize()
#     147 if self._keras_version == "keras_3":
#     148   if (self._mode == "v1" and
#     149       not self._submodule and
#     150       item.startswith("compat.v1.")):
#
# File ~/.local/lib/python3.10/site-packages/tensorflow/python/util/lazy_loader.py:116, in KerasLazyLoader._initialize(self)
#     113 try:
#     114   import keras  # pylint: disable=g-import-not-at-top
# --> 116   if keras.__version__.startswith("3."):
#     117     # This is the Keras 3.x case.
#     118     keras_version = "keras_3"
#     119     package_name = "keras._tf_keras.keras"
#
# AttributeError: partially initialized module 'keras' has no attribute '__version__' (most likely due to a circular import)

# %%
# import tensorflow as tf
from keras.utils import losses_utils
# from tensorflow.keras.losses import LossFunctionWrapper
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[11], line 2
#       1 # import tensorflow as tf
# ----> 2 from keras.utils import losses_utils
#
# File ~/.local/lib/python3.10/site-packages/keras/__init__.py:3
#       1 from __future__ import absolute_import
# ----> 3 from . import utils
#       4 from . import activations
#       5 from . import applications
#
# File ~/.local/lib/python3.10/site-packages/keras/utils/__init__.py:26
#      24 from .layer_utils import get_source_inputs
#      25 from .layer_utils import print_summary
# ---> 26 from .vis_utils import model_to_dot
#      27 from .vis_utils import plot_model
#      28 from .np_utils import to_categorical
#
# File ~/.local/lib/python3.10/site-packages/keras/utils/vis_utils.py:7
#       4 from __future__ import print_function
#       6 import os
# ----> 7 from ..models import Model
#       8 from ..layers.wrappers import Wrapper
#      10 # `pydot` is an optional dependency,
#      11 # see `extras_require` in `setup.py`.
#
# File ~/.local/lib/python3.10/site-packages/keras/models.py:12
#      10 from .engine.input_layer import Input
#      11 from .engine.input_layer import InputLayer
# ---> 12 from .engine.training import Model
#      13 from .engine.sequential import Sequential
#      14 from .engine.saving import save_model
#
# File ~/.local/lib/python3.10/site-packages/keras/engine/__init__.py:8
#       6 from .base_layer import Layer
#       7 from .network import get_source_inputs
# ----> 8 from .training import Model
#
# File ~/.local/lib/python3.10/site-packages/keras/engine/training.py:14
#      12 from .network import Network
#      13 from .base_layer import Layer
# ---> 14 from . import training_utils
#      15 from . import training_arrays
#      16 from . import training_generator
#
# File ~/.local/lib/python3.10/site-packages/keras/engine/training_utils.py:17
#      15 from .. import backend as K
#      16 from .. import losses
# ---> 17 from .. import metrics as metrics_module
#      18 from ..utils import Sequence
#      19 from ..utils import generic_utils
#
# File ~/.local/lib/python3.10/site-packages/keras/metrics.py:1850
#    1848     import tensorflow as tf
#    1849     if tf.__version__ >= '2.0.0':
# -> 1850         BaseMeanIoU = tf.keras.metrics.MeanIoU
#    1853 class MeanIoU(BaseMeanIoU):
#    1854     """Computes the mean Intersection-Over-Union metric.
#    1855
#    1856     Mean Intersection-Over-Union is a common evaluation metric for semantic image
#    (...)
#    1881         dtype: (Optional) data type of the metric result.
#    1882     """
#
# File ~/.local/lib/python3.10/site-packages/tensorflow/python/util/lazy_loader.py:147, in KerasLazyLoader.__getattr__(self, item)
#     145 if not self._initialized:
#     146   self._initialize()
# --> 147 if self._keras_version == "keras_3":
#     148   if (self._mode == "v1" and
#     149       not self._submodule and
#     150       item.startswith("compat.v1.")):
#     151     raise AttributeError(
#     152         "`tf.compat.v1.keras` is not available with Keras 3. Keras 3 has "
#     153         "no support for TF 1 APIs. You can install the `tf_keras` package "
#    (...)
#     156         "`tf.compat.v1.keras` to `tf_keras`."
#     157     )
#
# File ~/.local/lib/python3.10/site-packages/tensorflow/python/util/lazy_loader.py:147, in KerasLazyLoader.__getattr__(self, item)
#     145 if not self._initialized:
#     146   self._initialize()
# --> 147 if self._keras_version == "keras_3":
#     148   if (self._mode == "v1" and
#     149       not self._submodule and
#     150       item.startswith("compat.v1.")):
#     151     raise AttributeError(
#     152         "`tf.compat.v1.keras` is not available with Keras 3. Keras 3 has "
#     153         "no support for TF 1 APIs. You can install the `tf_keras` package "
#    (...)
#     156         "`tf.compat.v1.keras` to `tf_keras`."
#     157     )
#
#     [... skipping similar frames: KerasLazyLoader.__getattr__ at line 147 (2896 times)]
#
# File ~/.local/lib/python3.10/site-packages/tensorflow/python/util/lazy_loader.py:147, in KerasLazyLoader.__getattr__(self, item)
#     145 if not self._initialized:
#     146   self._initialize()
# --> 147 if self._keras_version == "keras_3":
#     148   if (self._mode == "v1" and
#     149       not self._submodule and
#     150       item.startswith("compat.v1.")):
#     151     raise AttributeError(
#     152         "`tf.compat.v1.keras` is not available with Keras 3. Keras 3 has "
#     153         "no support for TF 1 APIs. You can install the `tf_keras` package "
#    (...)
#     156         "`tf.compat.v1.keras` to `tf_keras`."
#     157     )
#
# File ~/.local/lib/python3.10/site-packages/tensorflow/python/util/lazy_loader.py:143, in KerasLazyLoader.__getattr__(self, item)
#     142 def __getattr__(self, item):
# --> 143   if item in ("_mode", "_initialized", "_name"):
#     144     return super(types.ModuleType, self).__getattribute__(item)
#     145   if not self._initialized:
#
# RecursionError: maximum recursion depth exceeded in comparison

# %%
from keras import utils
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 from keras import utils
#
# File ~/.local/lib/python3.10/site-packages/keras/__init__.py:3
#       1 from __future__ import absolute_import
# ----> 3 from . import utils
#       4 from . import activations
#       5 from . import applications
#
# File ~/.local/lib/python3.10/site-packages/keras/utils/__init__.py:26
#      24 from .layer_utils import get_source_inputs
#      25 from .layer_utils import print_summary
# ---> 26 from .vis_utils import model_to_dot
#      27 from .vis_utils import plot_model
#      28 from .np_utils import to_categorical
#
# File ~/.local/lib/python3.10/site-packages/keras/utils/vis_utils.py:7
#       4 from __future__ import print_function
#       6 import os
# ----> 7 from ..models import Model
#       8 from ..layers.wrappers import Wrapper
#      10 # `pydot` is an optional dependency,
#      11 # see `extras_require` in `setup.py`.
#
# File ~/.local/lib/python3.10/site-packages/keras/models.py:12
#      10 from .engine.input_layer import Input
#      11 from .engine.input_layer import InputLayer
# ---> 12 from .engine.training import Model
#      13 from .engine.sequential import Sequential
#      14 from .engine.saving import save_model
#
# File ~/.local/lib/python3.10/site-packages/keras/engine/__init__.py:8
#       6 from .base_layer import Layer
#       7 from .network import get_source_inputs
# ----> 8 from .training import Model
#
# File ~/.local/lib/python3.10/site-packages/keras/engine/training.py:14
#      12 from .network import Network
#      13 from .base_layer import Layer
# ---> 14 from . import training_utils
#      15 from . import training_arrays
#      16 from . import training_generator
#
# File ~/.local/lib/python3.10/site-packages/keras/engine/training_utils.py:17
#      15 from .. import backend as K
#      16 from .. import losses
# ---> 17 from .. import metrics as metrics_module
#      18 from ..utils import Sequence
#      19 from ..utils import generic_utils
#
# File ~/.local/lib/python3.10/site-packages/keras/metrics.py:1850
#    1848     import tensorflow as tf
#    1849     if tf.__version__ >= '2.0.0':
# -> 1850         BaseMeanIoU = tf.keras.metrics.MeanIoU
#    1853 class MeanIoU(BaseMeanIoU):
#    1854     """Computes the mean Intersection-Over-Union metric.
#    1855
#    1856     Mean Intersection-Over-Union is a common evaluation metric for semantic image
#    (...)
#    1881         dtype: (Optional) data type of the metric result.
#    1882     """
#
# File ~/.local/lib/python3.10/site-packages/tensorflow/python/util/lazy_loader.py:147, in KerasLazyLoader.__getattr__(self, item)
#     145 if not self._initialized:
#     146   self._initialize()
# --> 147 if self._keras_version == "keras_3":
#     148   if (self._mode == "v1" and
#     149       not self._submodule and
#     150       item.startswith("compat.v1.")):
#     151     raise AttributeError(
#     152         "`tf.compat.v1.keras` is not available with Keras 3. Keras 3 has "
#     153         "no support for TF 1 APIs. You can install the `tf_keras` package "
#    (...)
#     156         "`tf.compat.v1.keras` to `tf_keras`."
#     157     )
#
# File ~/.local/lib/python3.10/site-packages/tensorflow/python/util/lazy_loader.py:147, in KerasLazyLoader.__getattr__(self, item)
#     145 if not self._initialized:
#     146   self._initialize()
# --> 147 if self._keras_version == "keras_3":
#     148   if (self._mode == "v1" and
#     149       not self._submodule and
#     150       item.startswith("compat.v1.")):
#     151     raise AttributeError(
#     152         "`tf.compat.v1.keras` is not available with Keras 3. Keras 3 has "
#     153         "no support for TF 1 APIs. You can install the `tf_keras` package "
#    (...)
#     156         "`tf.compat.v1.keras` to `tf_keras`."
#     157     )
#
#     [... skipping similar frames: KerasLazyLoader.__getattr__ at line 147 (2900 times)]
#
# File ~/.local/lib/python3.10/site-packages/tensorflow/python/util/lazy_loader.py:147, in KerasLazyLoader.__getattr__(self, item)
#     145 if not self._initialized:
#     146   self._initialize()
# --> 147 if self._keras_version == "keras_3":
#     148   if (self._mode == "v1" and
#     149       not self._submodule and
#     150       item.startswith("compat.v1.")):
#     151     raise AttributeError(
#     152         "`tf.compat.v1.keras` is not available with Keras 3. Keras 3 has "
#     153         "no support for TF 1 APIs. You can install the `tf_keras` package "
#    (...)
#     156         "`tf.compat.v1.keras` to `tf_keras`."
#     157     )
#
# File ~/.local/lib/python3.10/site-packages/tensorflow/python/util/lazy_loader.py:143, in KerasLazyLoader.__getattr__(self, item)
#     142 def __getattr__(self, item):
# --> 143   if item in ("_mode", "_initialized", "_name"):
#     144     return super(types.ModuleType, self).__getattribute__(item)
#     145   if not self._initialized:
#
# RecursionError: maximum recursion depth exceeded in comparison
